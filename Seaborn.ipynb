# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset('tips')
sns.boxplot(data=df, x='day', y='total_bill', color='Green')
plt.title("Bill by Day")
plt.show()
